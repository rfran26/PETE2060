# %%
import numpy as np
import pandas as pd
import seaborn as sn
import scipy.stats as ss
import matplotlib.pyplot as plt
# import seaborn
import seaborn as sns
from scipy import stats
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\rfran26\Downloads\project_data.csv')
print (df)
# Out:
#               Rst        SGoil      SGgas  Psp    Tsp
# 0         scf/STB  Sgwater=1.0  SGair=1.0  PSI  deg F
# 1     1.608311631          0.8        0.6   15     70
# 2     11.90248659         0.61       0.88   69     72
# 3      10.6736522         0.58       0.66   80     62
# 4      7.70841785         0.88       0.81  199     88
# 5     4.341078559         0.76       0.62   86    122
# 6     13.21936011         0.61       0.74  141     95
# 7     6.911217789         0.83       0.83  124     90
# 8     4.483643127          0.9       0.82   82     86
# 9     4.225543993         0.67       0.73   36    135
# 10    10.43997082          0.7       0.66  154     53
# 11    3.849951469         0.87       0.86   45     73
# 12    7.797083612         0.65       0.81   72    131
# 13    2.751423939         0.86        0.6   51     69
# 14    9.271696094         0.69       0.68  159    102
# 15    8.908925529         0.64       0.78   80    101
# ...

# %%
##Data Analysis

# %%
df.shape
# Out:
# (1001, 5)

# %%
df.describe()
# Out:
#                 Rst SGoil SGgas   Psp   Tsp
# count          1001  1001  1001  1001  1001
# unique         1001    34    34   186    92
# top     3.231188548   0.9  0.77   177    90
# freq              1    40    48    12    20

# %%
df.tail()
# Out:
#               Rst SGoil SGgas  Psp  Tsp
# 996   5.084097287  0.67  0.69   44   87
# 997   7.004378298  0.81  0.63  153   51
# 998   6.208849593  0.78  0.61  177  113
# 999     1.9241094  0.84   0.7   19   78
# 1000  6.951001305  0.85  0.67  178   61

# %%
df.head()
# Out:
#            Rst        SGoil      SGgas  Psp    Tsp
# 0      scf/STB  Sgwater=1.0  SGair=1.0  PSI  deg F
# 1  1.608311631          0.8        0.6   15     70
# 2  11.90248659         0.61       0.88   69     72
# 3   10.6736522         0.58       0.66   80     62
# 4   7.70841785         0.88       0.81  199     88

# %%
sorted_by_gas_oil = df.sort_values(['Rst'], ascending=False)

# %%
sorted_by_gas_oil["Rst"].head(10)
# Out:
# 0          scf/STB
# 731    9.998025208
# 113    9.991276335
# 896    9.978749237
# 254    9.951035102
# 881    9.936406852
# 636    9.932133219
# 301    9.923255697
# 488     9.88933114
# 681    9.867396475
# Name: Rst, dtype: object

# %%
sorted(df)
# Out:
# ['Psp', 'Rst', 'SGgas', 'SGoil', 'Tsp']

# %%
df.dropna()
# Out:
#               Rst        SGoil      SGgas  Psp    Tsp
# 0         scf/STB  Sgwater=1.0  SGair=1.0  PSI  deg F
# 1     1.608311631          0.8        0.6   15     70
# 2     11.90248659         0.61       0.88   69     72
# 3      10.6736522         0.58       0.66   80     62
# 4      7.70841785         0.88       0.81  199     88
# 5     4.341078559         0.76       0.62   86    122
# 6     13.21936011         0.61       0.74  141     95
# 7     6.911217789         0.83       0.83  124     90
# 8     4.483643127          0.9       0.82   82     86
# 9     4.225543993         0.67       0.73   36    135
# 10    10.43997082          0.7       0.66  154     53
# 11    3.849951469         0.87       0.86   45     73
# 12    7.797083612         0.65       0.81   72    131
# 13    2.751423939         0.86        0.6   51     69
# 14    9.271696094         0.69       0.68  159    102
# 15    8.908925529         0.64       0.78   80    101
# ...

# %%
df.dropna(axis='columns')
# Out:
#               Rst        SGoil      SGgas  Psp    Tsp
# 0         scf/STB  Sgwater=1.0  SGair=1.0  PSI  deg F
# 1     1.608311631          0.8        0.6   15     70
# 2     11.90248659         0.61       0.88   69     72
# 3      10.6736522         0.58       0.66   80     62
# 4      7.70841785         0.88       0.81  199     88
# 5     4.341078559         0.76       0.62   86    122
# 6     13.21936011         0.61       0.74  141     95
# 7     6.911217789         0.83       0.83  124     90
# 8     4.483643127          0.9       0.82   82     86
# 9     4.225543993         0.67       0.73   36    135
# 10    10.43997082          0.7       0.66  154     53
# 11    3.849951469         0.87       0.86   45     73
# 12    7.797083612         0.65       0.81   72    131
# 13    2.751423939         0.86        0.6   51     69
# 14    9.271696094         0.69       0.68  159    102
# 15    8.908925529         0.64       0.78   80    101
# ...

# %%
df.dropna(how='all')
# Out:
#               Rst        SGoil      SGgas  Psp    Tsp
# 0         scf/STB  Sgwater=1.0  SGair=1.0  PSI  deg F
# 1     1.608311631          0.8        0.6   15     70
# 2     11.90248659         0.61       0.88   69     72
# 3      10.6736522         0.58       0.66   80     62
# 4      7.70841785         0.88       0.81  199     88
# 5     4.341078559         0.76       0.62   86    122
# 6     13.21936011         0.61       0.74  141     95
# 7     6.911217789         0.83       0.83  124     90
# 8     4.483643127          0.9       0.82   82     86
# 9     4.225543993         0.67       0.73   36    135
# 10    10.43997082          0.7       0.66  154     53
# 11    3.849951469         0.87       0.86   45     73
# 12    7.797083612         0.65       0.81   72    131
# 13    2.751423939         0.86        0.6   51     69
# 14    9.271696094         0.69       0.68  159    102
# 15    8.908925529         0.64       0.78   80    101
# ...

# %%
df.drop([0], axis=0)

# %%
df
# Out:
#               Rst SGoil SGgas  Psp  Tsp
# 1     1.608311631   0.8   0.6   15   70
# 2     11.90248659  0.61  0.88   69   72
# 3      10.6736522  0.58  0.66   80   62
# 4      7.70841785  0.88  0.81  199   88
# 5     4.341078559  0.76  0.62   86  122
# 6     13.21936011  0.61  0.74  141   95
# 7     6.911217789  0.83  0.83  124   90
# 8     4.483643127   0.9  0.82   82   86
# 9     4.225543993  0.67  0.73   36  135
# 10    10.43997082   0.7  0.66  154   53
# 11    3.849951469  0.87  0.86   45   73
# 12    7.797083612  0.65  0.81   72  131
# 13    2.751423939  0.86   0.6   51   69
# 14    9.271696094  0.69  0.68  159  102
# 15    8.908925529  0.64  0.78   80  101
# 16     6.67257748  0.82   0.8  153  139
# 17    4.541862019  0.86  0.81   69   81
# 18    4.354997527   0.8  0.62  100  108
# 19     4.08354849   0.9  0.65  109   77
# 20    13.99214832  0.67  0.81  142   57
# 21    8.955666159  0.65  0.65  145  126
# 22    15.73783058  0.61  0.89  151  129
# ...

# %%
values = [5, 10, 15, 20]

plt.boxplot(values)
plt.yticks(range(1, 22))
plt.ylabel("Value")
plt.show()

# %%
df.dtypes
# Out:
# Rst      object
# SGoil    object
# SGgas    object
# Psp      object
# Tsp      object
# dtype: object

# %%
df = df.convert_objects(convert_numeric=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
df.dtypes
# Out:
# Rst      float64
# SGoil    float64
# SGgas    float64
# Psp        int64
# Tsp        int64
# dtype: object

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# Rst       4.873349
# SGoil     0.170000
# SGgas     0.160000
# Psp      89.250000
# Tsp      45.000000
# dtype: float64

# %%
print(df < (Q1 - 1.5 * IQR))
print(df > (Q3 + 1.5 * IQR))
# Out:
#         Rst  SGoil  SGgas    Psp    Tsp
# 1     False  False  False  False  False
# 2     False  False  False  False  False
# 3     False  False  False  False  False
# 4     False  False  False  False  False
# 5     False  False  False  False  False
# 6     False  False  False  False  False
# 7     False  False  False  False  False
# 8     False  False  False  False  False
# 9     False  False  False  False  False
# 10    False  False  False  False  False
# 11    False  False  False  False  False
# 12    False  False  False  False  False
# 13    False  False  False  False  False
# 14    False  False  False  False  False
# 15    False  False  False  False  False
# 16    False  False  False  False  False
# 17    False  False  False  False  False
# 18    False  False  False  False  False
# 19    False  False  False  False  False
# 20    False  False  False  False  False
# 21    False  False  False  False  False
# 22    False  False  False  False  False
# ...

# %%
df_out = df[~((df<(Q1-1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df_out.shape
# Out:
# (974, 5)

# %%
## Outliers Have Been Removed?

# %%
SGoil = df['SGoil']
Rst = df['Rst']

plt.scatter(Rst, SGoil)
plt.title("Correlation for Rst")
plt.xlabel("SGoil")
plt.ylabel("Rst")
plt.show()

# %%
df.plot.scatter("SGoil", "Rst")

# %%
df.plot.scatter("SGgas", "Rst")
plt.show()

# %%
df.plot.scatter("Psp", "Rst")
plt.show()

# %%
df.plot.scatter ("Tsp", "Rst")

# %%
Rst = df['Rst']
SGoil = df['SGoil']
plt.scatter(Rst, SGoil , edgecolors='y')
plt.ylabel('Rst')
plt.xlabel('SGoil')
plt.title('SGoil v. Rst')
plt.show()

# %%
Rst = df['Rst']
SGgas = df['SGgas']
plt.scatter(Rst, SGgas , edgecolors='b')
plt.ylabel('Rst')
plt.xlabel('SGgas')
plt.title('SGgas v. Rst')
plt.show()

# %%
Rst = df['Rst']
Psp = df['Psp']
plt.scatter(Rst, Psp , edgecolors='r')
plt.ylabel('Psp')
plt.xlabel('Rst')
plt.title('Psp v. Rst')
plt.show()

# %%
Rst = df['Rst']
Tsp = df['Tsp']
plt.scatter(Rst, Tsp , edgecolors='m')
plt.ylabel('Tsp')
plt.xlabel('Rst')
plt.title('Tsp v. Rst')
plt.show()

# %%
df['log_Psp']=np.log(df.Psp)
df['log_Tsp']=np.log(df.Tsp)
df['log_Rst']=np.log(df.Rst)
df['log_SGoil']=np.log(df.SGoil)
df['log_SGgas']=np.log(df.SGgas)
df
# Out:
#             Rst  SGoil  SGgas  Psp  Tsp   log_Psp   log_Tsp   log_Rst  \
# 1      1.608312   0.80   0.60   15   70  2.708050  4.248495  0.475185
# 2     11.902487   0.61   0.88   69   72  4.234107  4.276666  2.476747
# 3     10.673652   0.58   0.66   80   62  4.382027  4.127134  2.367778
# 4      7.708418   0.88   0.81  199   88  5.293305  4.477337  2.042313
# 5      4.341079   0.76   0.62   86  122  4.454347  4.804021  1.468123
# 6     13.219360   0.61   0.74  141   95  4.948760  4.553877  2.581682
# 7      6.911218   0.83   0.83  124   90  4.820282  4.499810  1.933146
# 8      4.483643   0.90   0.82   82   86  4.406719  4.454347  1.500436
# 9      4.225544   0.67   0.73   36  135  3.583519  4.905275  1.441148
# 10    10.439971   0.70   0.66  154   53  5.036953  3.970292  2.345642
# 11     3.849951   0.87   0.86   45   73  3.806662  4.290459  1.348061
# 12     7.797084   0.65   0.81   72  131  4.276666  4.875197  2.053750
# ...

# %%
plt.scatter(df.log_Psp,df.log_Rst)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.scatter(df.log_Tsp,df.log_Rst)
plt.show()

# %%
plt.scatter(df.log_Tsp,df.log_Rst)
plt.show()

# %%
plt.scatter(df.log_SGgas,df.log_Rst)
plt.show()

# %%
import statsmodels.api as sm
from sklearn import linear_model

# %%
df
# Out:
#             Rst  SGoil  SGgas  Psp  Tsp   log_Psp   log_Tsp   log_Rst  \
# 1      1.608312   0.80   0.60   15   70  2.708050  4.248495  0.475185
# 2     11.902487   0.61   0.88   69   72  4.234107  4.276666  2.476747
# 3     10.673652   0.58   0.66   80   62  4.382027  4.127134  2.367778
# 4      7.708418   0.88   0.81  199   88  5.293305  4.477337  2.042313
# 5      4.341079   0.76   0.62   86  122  4.454347  4.804021  1.468123
# 6     13.219360   0.61   0.74  141   95  4.948760  4.553877  2.581682
# 7      6.911218   0.83   0.83  124   90  4.820282  4.499810  1.933146
# 8      4.483643   0.90   0.82   82   86  4.406719  4.454347  1.500436
# 9      4.225544   0.67   0.73   36  135  3.583519  4.905275  1.441148
# 10    10.439971   0.70   0.66  154   53  5.036953  3.970292  2.345642
# 11     3.849951   0.87   0.86   45   73  3.806662  4.290459  1.348061
# 12     7.797084   0.65   0.81   72  131  4.276666  4.875197  2.053750
# ...

# %%
X = df[['log_SGoil','log_SGgas','log_Psp','log_Tsp']]

Y = df['log_Rst']

regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  0.381799999977
# Coefficients:
#  [-2.39122542  1.26032259  0.57630878 -0.31942359]
#                             OLS Regression Results
# ...
# Dep. Variable:                log_Rst   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.940e+06
# Date:                Fri, 03 May 2019   Prob (F-statistic):               0.00
# Time:                        12:42:03   Log-Likelihood:                 2394.7
# No. Observations:                1000   AIC:                            -4781.
# Df Residuals:                     996   BIC:                            -4762.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
df["Rst"].apply(np.log).hist()
df["SGgas"].apply(np.log).hist()
plt.show()

# %%
df["SGgas"].apply(np.log).hist()
df["SGoil"].apply(np.log).hist()
plt.show()

# %%
df["Psp"].apply(np.log).hist()
df["Rst"].apply(np.log).hist()
plt.show()

# %%
df["Tsp"].apply(np.log).hist()
df["Rst"].apply(np.log).hist()
plt.show()
